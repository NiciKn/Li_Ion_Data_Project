# %% [markdown]
# # NASA randomized and recommissioned battery dataset
#
# An accelerated Life Testing Dataset for Lithium-Ion Batteries with Constant and Variable Loading Conditions:
#
# The dataset repository is organized into three main folders, each containing one group of life cycled battery packs.
# Within each folder individual battery packs own their dedicated csv file for continuous data logging, which are named with their respective battery pack number.
#
# The folders are named:
#
# - regular_alt_batteries: Containing one csv file for each battery pack cycled at the same load level or load range throughout lifetime
# - recommissioned_batteries: Containing one csv file for each battery pack cycled at different load levels at varying life stages
# - second_life_batteries: Containing one csv file for each second life battery pack cycled at constant current througout the second life
#
# The columns in each csv file contain the following data with the provided units:
#
# The following columns contain data throughout the cycling process:
#
# - start time: [mm:dd:yyyy hh:mm:ss] (start time of each cycle day for each battery pack, in most cases approximately 24h)
# - relative time: [s] (the relative time is continuous from the beginning of the entire life cycle to the failure of each battery pack)
# - mode: -1 = discharge, 0 = rest, 1 = charge
# - voltage charger: [V] (continuous battery pack voltage measurement right after the connection of the battery pack to the charger board)
# - temperature battery: [C] (continuous temperature measurement on the battery cell electrode surface)
#
# Those columns only contain data when the respective battery is connected to the load board and performing a discharge mission
#
# - voltage load: [V] (battery pack voltage measured on the load board)
# - current load: [A] (discharge current measured on the load board using current sense resistors)
# - temperature mosfet: [C] (temperature on the load board mosfets, measured for safety purposes)
# - temperature resistor: [C] (temperature on the load board current sense resistor, measured for safety purposes)
# - mission type: 0 = reference discharge (constant current at 2.5A), 1 = regular mission
#
# Please cite this dataset using:
#
# ```
# @misc{2023_alt_dataset_fricke_et_al,
# 	Author = {Kajetan Fricke and Renato G. Nascimento and Felipe A. C. Viana},
# 	Doi = {},
# 	Howpublished = {},
# 	Month = {July},
# 	Publisher = {nasa-data@lists.arc.nasa.gov},
# 	Title = {An accelerated Life Testing Dataset for Lithium-Ion Batteries with Constant and Variable Loading Conditions},
# 	Url = {},
# 	Version = {0.0.1},
# 	Year = {2023}}
# ```
#
# The corresponding reference entry should look like:
# An accelerated Life Testing Dataset for Lithium-Ion Batteries with Constant and Variable Loading Conditions, v0.0.1,
#
# ### Publications
#
# The following publications out of the PML-UCF research group used/referred to this repository:
# - K. Fricke, R. G. Nascimento, M. Corbetta, C. S. Kulkarni, F. A. C. Viana, "[Prognosis of Li-ion Batteries Under Large Load Variations Using Hybrid Physics-Informed Neural Networks]"
# - K. Fricke, R. G. Nascimento, M. Corbetta, C. S. Kulkarni, F. A. C. Viana, "[An accelerated Life Testing Dataset for Lithium-Ion Batteries with Constant and Variable Loading Conditions]"
#
#
# ## Regular accelerated life test (regular alt batteries folder):
#
# This folder contains the data files from battery packs subject to constant and variable loading conditions,
# where the current range of the latter remains the same throughout the battery life.
#
# The assigned battery packs in this folder are numbered as
# follows:
#
# – Constant current:
# Those battery packs were subjected to the same load level during discharge missions over their respective life time.
#
# The here provided averaged current levels are approximated, and might vary slightly:
#
# * 9.30A: Battery pack 0.1 and 1.1
# * 12.9A: Battery pack 3.1 and 2.2
# * 14.3A: Battery pack 2.3 and 5.2
# * 16.0A: Battery pack 0.0 and 1.0
# * 19.0A: Battery pack 2.0, 3.0 and 2.1
#
# – Variable current:
#
# Those battery packs are subjected to variable current within a discharge cycle.
# The current level segments are kept constant for either 40, 60 or 80 seconds before switching to another level.
# Both, the amplitude and length of each current level segments was randomly selected to create a pool of different random loading discharge missions.
#
# The here provided averaged current levels are approximated, and might vary slightly:
#
# * 14.3A average (12.9A - 16A range): Battery pack 4.1 and 5.1
# * 17.0A average (16A - 19A range): Battery pack 4.0 and 5.0
#
#
# ## Recommissioned batteries (recommissioned batteries folder):
#
# This folder contains the data files from battery packs where the constant loading conditions were changed throughout the battery life.
# The assigned battery packs in this folder are numbered as follows:
#
# – Two life stages:
# The following batteries were subjected to constant current levels at the first provided amplitudes until reaching an capacity level of approximately 2.2Ah,
# and then switched to the second current level until reaching end of life
#
# The here provided averaged current levels are approximated, and might vary slightly:
#
# * 16A, 14.3A: Battery pack 3.2
# * 14.3A, 16A: Battery pack 5.3
# * 16A, 12.9A: Battery pack 0.2 and 3.3
# * 16A, 9.30A: Battery pack 1.2 and 2.4
#
# – Three life stages:
# Those batteries were subjected to current level switches at approximately 2.2Ah and 2.0Ah of capacity.
# The here provided averaged current levels are approximated, and might vary slightly:
#
# * 16A, 14.3A, 7.5A: Battery pack 0.3
# * 16A, 7.5A, 14.3A: Battery pack 2.5
#
#
# ## Second life batteries (second life batteries folder):
#
# This folder contains the data files from battery packs that consist of battery cells survived from previously cycled battery packs.
# The assigned battery packs in this folder are numbered as follows:
#
# – 2nd life battery packs:
# The following batteries were subjected to constant current levels at the first provided amplitudes until reaching end of life (EOL).
# Survivor cells were then reused and subjected to the second provided current level until reaching EOL
#
# The here provided averaged current levels are approximated, and might vary slightly:
#
# * 16.0A, 9.3A: Battery pack 1.3 (First life battery packs: 0.0 & 1.1)
# * 14.3A, 7.5A: Battery pack 3.6 (First life battery packs: 2.3 & 5.2)
# * 12.9A, 5.0A: Battery pack 5.4 (First life battery packs: 2.2 & 3.1)

# %%
import pandas as pd
import numpy as np

file = "battery01.csv"
path = "battery_alt_dataset/battery_alt_dataset/regular_alt_batteries/"
path += file

df_in = pd.read_csv(path)

# %%
df_in.head(3)
# Out:
#             start_time   time  mode  voltage_charger  temperature_battery  \
# 0  2022-08-12 21:09:00  0.000   0.0            0.000                0.000
# 1  2022-08-12 21:09:00  1.184   0.0            7.378               22.733
# 2  2022-08-12 21:09:00  2.141   0.0            7.379               22.733
#
#    voltage_load  current_load  temperature_mosfet  temperature_resistor  \
# 0           NaN           NaN                 NaN                   NaN
# 1           NaN           NaN                 NaN                   NaN
# 2           NaN           NaN                 NaN                   NaN
#
#    mission_type
# 0           NaN
# 1           NaN
# 2           NaN

# %%
df_in.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4918193 entries, 0 to 4918192
# Data columns (total 10 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   start_time            object
#  1   time                  float64
#  2   mode                  float64
#  3   voltage_charger       float64
#  4   temperature_battery   float64
#  5   voltage_load          float64
#  6   current_load          float64
#  7   temperature_mosfet    float64
#  8   temperature_resistor  float64
#  9   mission_type          float64
# dtypes: float64(9), object(1)
# memory usage: 375.2+ MB

# %%
df_in.describe(include='all')
# Out:
#                  start_time          time          mode  voltage_charger  \
# count               4918193  4.918193e+06  4.918193e+06     4.918193e+06
# unique                   74           NaN           NaN              NaN
# top     2022-09-21 13:41:00           NaN           NaN              NaN
# freq                  95926           NaN           NaN              NaN
# mean                    NaN  2.470560e+06  3.382427e-01     7.436095e+00
# std                     NaN  1.428927e+06  7.269148e-01     9.531622e-01
# min                     NaN  0.000000e+00 -1.000000e+00    -6.000000e-02
# 25%                     NaN  1.234353e+06  0.000000e+00     6.705000e+00
# 50%                     NaN  2.464022e+06  0.000000e+00     7.710000e+00
# 75%                     NaN  3.704637e+06  1.000000e+00     8.217000e+00
# max                     NaN  4.951798e+06  1.000000e+00     9.177000e+00
#
#         temperature_battery   voltage_load   current_load  temperature_mosfet  \
# count          4.918193e+06  748968.000000  748968.000000       748968.000000
# unique                  NaN            NaN            NaN                 NaN
# top                     NaN            NaN            NaN                 NaN
# freq                    NaN            NaN            NaN                 NaN
# mean           3.466781e+01       6.695055       8.465880           29.118428
# std            9.549272e+00       0.637043       2.675197            2.051429
# min            0.000000e+00      -0.027000       0.150000           21.520000
# 25%            2.865200e+01       6.310000       9.324779           29.060000
# 50%            3.271100e+01       6.707000       9.689100           29.850000
# 75%            3.699400e+01       7.108000       9.760744           30.400000
# max            7.273300e+01       8.730000      10.373175           33.740000
#
#         temperature_resistor   mission_type
# count          748968.000000  748968.000000
# unique                   NaN            NaN
# top                      NaN            NaN
# freq                     NaN            NaN
# mean               25.557998       0.835985
# std                 1.343392       0.370289
# min                21.730000       0.000000
# 25%                25.460000       1.000000
# 50%                25.950000       1.000000
# 75%                26.180000       1.000000
# max                32.460000       1.000000

# %%
#Clean data and drop not used columns
def clean_data(df_in):
    df = df_in.copy()
    df['temperature_battery'] = df['temperature_battery'].astype(float)

    # fill NA values of temperature and replace unrealistic values
    mean_temp = df['temperature_battery'].mean()
    df['temperature_battery'] = df['temperature_battery'].fillna(mean_temp)
    
    def replace_negative_temp(x):
        if x <= 0:
            return mean_temp
        else:
            return x
    
    df['temperature_battery'] = df['temperature_battery'].apply(replace_negative_temp)
    df['current_load'] = df['current_load'].fillna(0)
    df = df.drop(columns=['start_time','temperature_mosfet','temperature_resistor','voltage_load'])

    # remove voltage zero values
    idx = df[(df['voltage_charger']==0)].index
    df.drop(index=idx,axis=0,inplace=True)

    # Calculate delta t
    time_array = np.array(df['time'])
    delta_t_array = time_array[1:] - time_array[:-1]
    delta_t_list = list(delta_t_array)
    delta_t_list = [0] + delta_t_list
    delta_t_array = np.array(delta_t_list)
    df['delta_t'] = pd.Series(delta_t_array)
    
    return df

df = clean_data(df_in)

df.head(3)
# Out:
#     time  mode  voltage_charger  temperature_battery  current_load  \
# 1  1.184   0.0            7.378               22.733           0.0
# 2  2.141   0.0            7.379               22.733           0.0
# 3  3.105   0.0            7.378               22.733           0.0
#
#    mission_type  delta_t
# 1           NaN    0.957
# 2           NaN    0.964
# 3           NaN    1.107

# %%
import matplotlib.pyplot as plt
import seaborn as sns

print("Hello")

cycle_start = df[(df['time'] < 56000) & (df['time'] > 0)]
#cycle_end = df[(df['time'] < 3878000) & (df['time'] > 3889000)]
cycle_end = df[(df['time'] < 41E5) & (df['time'] > 38E5)]

plt.figure(figsize=(20,20))

fig, axes = plt.subplots(nrows=2, figsize=(10,20))

sns.lineplot(data=cycle_start, x='time', y='voltage_charger',ax=axes[0])
#sns.lineplot(data=cycle_start, x='time', y='current_load',ax=axes[0])

sns.lineplot(data=cycle_end, x='time', y='voltage_charger',ax=axes[1])
#sns.lineplot(data=cycle_end, x='time', y='current_load',ax=axes[1])


for ax in axes:
    ax.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()
# Out:
# Hello

# %%
def calc_Q_V(data,voltages,nom_cap_mAh,min_start_voltage):
    '''
    Calculates the normalized discharge from full charge for given voltage points
    '''
    Q_norm = []
    if data.iloc[0]['voltage_charger'] < min_start_voltage:
        return False, []
    i=0
    for idx in range(len(voltages)):
        voltage = voltages[idx]
        while i < len(data)-1 and data.iloc[i]['voltage_charger'] > voltage:        
            i += 1
        q = (data.iloc[:i]['current_load'] * data.iloc[:i]['delta_t']).sum()
        Q_norm.append(q/3.6/nom_cap_mAh)
    return True, Q_norm

def return_inner_res_mOhm(data,min_curr,min_volt_drop):
    '''
    Calculates the inner resistance when the mode changes from discharge to idle
    '''
    i=0
    inner_resistance = 0
    last_idx = 0
    last_res = 0
    
    #check when mode goes into discharge
    while i < len(data) and data.iloc[i]['mode'] != -1:
        i += 1
        
    #check when mode goes into idle
    while i < len(data) and data.iloc[i]['mode'] != 0:
        i += 1
        
    #only calc inner resistance when discharge current is over a threshold
    current = data.iloc[i-1]['current_load']
    meas_OK = False
    if current > min_curr:
        voltage_discharge = data.iloc[i-1]['voltage_charger']
        #check when voltage increases a threshold to get the ohmic voltage drop
        #and no relaxation voltage drop
        offset=0
        while offset < 10:
            voltage = data.iloc[i+offset]['voltage_charger']
            if voltage > (voltage_discharge + min_volt_drop):
                voltage_open = voltage
                inner_resistance = 1000*(voltage_open - voltage_discharge)/current
                meas_OK = True
                break
            offset += 1
    return meas_OK, inner_resistance

def isReferenceCycle(data):
    '''
    checks if given cycle is a reference cycle with 2.5A discharge
    '''
    for i in range(len(data)):
        if (data.iloc[i]['mission_type'] == 0) and (2 < data.iloc[i]['current_load'] < 3):
            return True
    return False

def calc_charge(data):
    '''
    calculates the full charge throuput for the given data
    '''
    charge_As = (data['current_load']*data['delta_t']).sum()
    charge_mAh = charge_As / 3.6
    return charge_mAh

def calc_energy(data):
    '''
    calculates the full energy throuput for the given data
    '''
    energy_Ws = (data['current_load']*data['voltage_charger']*data['delta_t']).sum()
    energy_Wh = energy_Ws/3600
    return energy_Wh

def calc_hist(feature,data,bins):
    '''
    Calculates histogram and avg,max,min for a given feature
    '''
    hist = [0]*(len(bins)+1)

    maxi = data[feature].max()
    avg = (data[feature] * data['delta_t']).sum() / data['delta_t'].sum()
    mini = data[feature].min()

    for i in range(1,len(bins)):
        tmp = data[(data[feature]<bins[i]) & (data[feature]>=bins[i-1])]  
        hist[i] = tmp['delta_t'].sum()

    tmp = data[data[feature]<bins[0]]
    hist[0] = tmp['delta_t'].sum()

    tmp = data[data[feature]>bins[-1]]
    hist[-1] = tmp['delta_t'].sum()
    
    return hist, maxi, avg, mini


def return_full_charged_cycle_indices(data, charged_volt, discharged_volt):
    '''
    return all indices where a new cycle starts
    '''
    indices = []
    max_idx = len(data) - 1
    voltage = 'voltage_charger'
    i=0
    
    # check time when battery is fully charged
    while i < max_idx:
        if data.iloc[i]['mode']==0 and data.iloc[i][voltage] >= charged_volt:
            break
        i += 1
    
    while i < max_idx:
        indices.append(i)
        # wait until battery is discharging
        while (i < len(data)) and (data.iloc[i]['mode'] != -1):
            i += 1
        
        # check time when battery is fully discharged
        charged = False
        while i < max_idx:
            if data.iloc[i]['mode']==0 and data.iloc[i][voltage] <= discharged_volt:
                break         
            i += 1

        # check time when battery is fully charged
        while i < max_idx:
            if data.iloc[i]['mode']==0 and data.iloc[i][voltage] >= charged_volt:
                break
            i += 1
            
    return indices
    

def generate_cycle_based_data(batt_label, data):
    """
    Generate cycle based data from the time based full cycle battery test data
    """
    d = {}
    d['batt_label'] = []
    d['isRefCycle'] = []
    d['time_sec'] = []

    d['EFC'] = []
    d['E_cum_norm'] = []

    d['T_avg'] = []
    d['T_max'] = []
    d['T_min'] = []
    d['perc_T_st_-20'] = []
    d['perc_T_-20_0'] = []
    d['perc_T_0_20'] = []
    d['perc_T_20_40'] = []
    d['perc_T_40_60'] = []
    d['perc_T_60_80'] = []
    d['perc_T_80_100'] = []
    d['perc_T_gt_100'] = []
    
    d['C_rate_avg'] = []
    d['C_rate_max'] = []
    d['perc_C_rate_0_0.5'] = []
    d['perc_C_rate_0.5_1'] = []
    d['perc_C_rate_1_2'] = []
    d['perc_C_rate_2_3'] = []
    d['perc_C_rate_3_4'] = []
    d['perc_C_rate_4_6'] = []
    d['perc_C_rate_6_8'] = []
    d['perc_C_rate_gt_8'] = []

    d['Q_norm_at_3.8_V'] = []
    d['Q_norm_at_3.6_V'] = []
    d['Q_norm_at_3.4_V'] = []
    d['Q_norm_at_3.2_V'] = []

    d['R_norm'] = []
    d['SOH'] = []

    temp_bins = [-20,0,20,40,60,80,100]
    temp_hist = np.array(8*[0.0])
    temp_hist_perc = np.array(8*[0.0])
    sum_temp = 0
    avg_temp = 0
    max_temp = -1000
    min_temp = 1000

    curr_bins_C = np.array([0.5,1,2,3,4,6,8])
    curr_hist = np.array(8*[0.0])
    curr_hist_perc = np.array(8*[0.0])
    sum_curr = 0
    avg_curr = 0
    max_curr = -1000
    min_curr = 1000

    voltage_points = [7.6,7.2,6.8,6.4]
    Q_values = [0] * len(voltage_points)

    sum_Q_mAh = 0
    sum_E_Wh = 0

    inner_res_norm = 1
    first_res_meas = False
    nom_res_mOhm = 40

    indices = return_full_charged_cycle_indices(data, 8, 6.3)
    #print(indices)

    ref_indices = []
    first_idx = indices[0]
    
    for i in range(0,len(indices)-1):
        d['batt_label'].append(batt_label)
        start_idx = indices[i]
        end_idx = indices[i+1]
        
        cycle = data.iloc[start_idx:end_idx]
        referenceCycle = isReferenceCycle(cycle)
        d['isRefCycle'].append(referenceCycle)
        d['time_sec'].append(cycle.iloc[-1]['time'])

        charge_mAh = calc_charge(cycle)
        energy_Wh = calc_energy(cycle)

        sum_Q_mAh += charge_mAh
        sum_E_Wh += energy_Wh

        # Calculate nom_capacity_mAh when first cycle
        if i == 0:
            nom_capacity_mAh = charge_mAh
            curr_bins_A = curr_bins_C * nom_capacity_mAh / 1000
            nom_Energy_Wh = energy_Wh

        if referenceCycle:
            ref_indices.append(i)
            ret, Q_values = calc_Q_V(cycle,voltage_points,nom_capacity_mAh,8)
            if not ret:
                Q_values = [0] * len(voltage_points)
        else:
            Q_values = [0] * len(voltage_points)

        d['Q_norm_at_3.8_V'].append(Q_values[0])
        d['Q_norm_at_3.6_V'].append(Q_values[1])
        d['Q_norm_at_3.4_V'].append(Q_values[2])
        d['Q_norm_at_3.2_V'].append(Q_values[3])

        sum_Q_norm = sum_Q_mAh / nom_capacity_mAh
        sum_E_norm = sum_E_Wh / nom_Energy_Wh

        d['EFC'].append(sum_Q_norm)
        d['E_cum_norm'].append(sum_E_norm)

        soh = 100*charge_mAh/nom_capacity_mAh
        d['SOH'].append(soh)

        #Calculate inner resistance
        meas_ok, tmp_res = return_inner_res_mOhm(cycle,8,0.1)

        if meas_ok:
            inner_res_mOhm = tmp_res
            if not first_res_meas:
                first_res_meas = True
                nom_res_mOhm = inner_res_mOhm
            else:
                inner_res_norm = inner_res_mOhm / nom_res_mOhm

        d['R_norm'].append(inner_res_norm)
        
        #print(soh)
        #print(sum_Q_norm)
        #print(sum_E_norm)
            
        #print(nom_capacity_mAh)
        #print(curr_bins_A)
        
        #Do temperature calculations here
        temp_hist_cycle, max_temp_cycle, avg_temp_cycle, min_temp_cycle = calc_hist('temperature_battery',cycle,temp_bins)
        temp_hist += np.array(temp_hist_cycle)
        temp_hist_perc = 100 * temp_hist / temp_hist.sum()
        sum_temp += avg_temp_cycle * (data.iloc[end_idx]['time'] - data.iloc[start_idx]['time'])
        avg_temp = sum_temp / (data.iloc[end_idx]['time'] - data.iloc[first_idx]['time'])
        if max_temp_cycle > max_temp:
            max_temp = max_temp_cycle
        if min_temp_cycle < min_temp:
            min_temp = min_temp_cycle

        d['T_avg'].append(avg_temp)
        d['T_max'].append(max_temp)
        d['T_min'].append(min_temp)
        d['perc_T_st_-20'].append(temp_hist_perc[0])
        d['perc_T_-20_0'].append(temp_hist_perc[1])
        d['perc_T_0_20'].append(temp_hist_perc[2])
        d['perc_T_20_40'].append(temp_hist_perc[3])
        d['perc_T_40_60'].append(temp_hist_perc[4])
        d['perc_T_60_80'].append(temp_hist_perc[5])
        d['perc_T_80_100'].append(temp_hist_perc[6])
        d['perc_T_gt_100'].append(temp_hist_perc[7])

        #print(temp_hist_perc)
        #print(max_temp)
        #print(avg_temp)
        #print(start_idx)
        
        #Do current calculations here  
        curr_hist_cycle, max_curr_cycle, avg_curr_cycle, min_curr_cycle = calc_hist('current_load',cycle,curr_bins_A)
        curr_hist += np.array(curr_hist_cycle)
        curr_hist_perc = 100 * curr_hist / curr_hist.sum()
        sum_curr += avg_curr_cycle * (data.iloc[end_idx]['time'] - data.iloc[start_idx]['time'])
        avg_curr_C = sum_curr / (data.iloc[end_idx]['time'] - data.iloc[first_idx]['time']) * 1000 / nom_capacity_mAh
        if max_curr_cycle > max_curr:
            max_curr = max_curr_cycle
            max_curr_C = 1000 * max_curr / nom_capacity_mAh

        d['C_rate_avg'].append(avg_curr_C)
        d['C_rate_max'].append(max_curr_C)
        d['perc_C_rate_0_0.5'].append(curr_hist_perc[0])
        d['perc_C_rate_0.5_1'].append(curr_hist_perc[1])
        d['perc_C_rate_1_2'].append(curr_hist_perc[2])
        d['perc_C_rate_2_3'].append(curr_hist_perc[3])
        d['perc_C_rate_3_4'].append(curr_hist_perc[4])
        d['perc_C_rate_4_6'].append(curr_hist_perc[5])
        d['perc_C_rate_6_8'].append(curr_hist_perc[6])
        d['perc_C_rate_gt_8'].append(curr_hist_perc[7])

    
        #print(curr_hist_perc)
        #print(max_curr_C)
        #print(avg_curr_C)

    
    # Make linear interpolation for Q(V)
    max_idx = max(ref_indices)
    min_idx = min(ref_indices)

    feat_names = ['Q_norm_at_3.8_V', 'Q_norm_at_3.6_V', 'Q_norm_at_3.4_V', 'Q_norm_at_3.2_V']
        
    for i in range(0,len(indices)-1):
        if i > max_idx:
            for feat_name in feat_names:
                d[feat_name][i] = d[feat_name][max_idx]
        elif i < min_idx:
            for feat_name in feat_names:
                d[feat_name][i] = d[feat_name][min_idx]
        elif i not in ref_indices:
            for j,v in enumerate(ref_indices):
                if v > i:
                    # Found right index
                    x = 2*[0]
                    y = 2*[0]
                    x[0] = d['EFC'][ref_indices[j-1]]
                    x[1] = d['EFC'][v]
                    for feat_name in feat_names:
                        y[0] = d[feat_name][ref_indices[j-1]]
                        y[1] = d[feat_name][v]
                        x_interp = d['EFC'][i]
                        y_interp = np.interp(x_interp, x, y)     
                        d[feat_name][i] = y_interp
                    break
        
        
    ret = pd.DataFrame(d)
    return ret

cycle_based_df = generate_cycle_based_data("battery20",df)
cycle_based_df.to_csv("cycles_battery20.csv")
cycle_based_df
# Out:
#     batt_label  isRefCycle     time_sec         EFC  E_cum_norm      T_avg  \
# 0    battery20        True    56111.058    1.000000    1.000000  26.624348
# 1    battery20       False    61330.696    1.992376    1.942908  29.810862
# 2    battery20       False    66548.284    2.983919    2.884960  30.944088
# 3    battery20       False    76540.505    3.971898    3.820947  30.121889
# 4    battery20       False    81742.236    4.959064    4.758444  30.724315
# ..         ...         ...          ...         ...         ...        ...
# 857  battery20       False  4928557.253  718.824908  651.889754  34.771664
# 858  battery20       False  4932961.391  719.560426  652.527105  34.777757
# 859  battery20       False  4937646.269  720.294604  653.161623  34.783362
# 860  battery20        True  4944285.651  721.035231  653.836018  34.780949
# 861  battery20       False  4946085.940  721.691045  654.414061  34.784865
#
#       T_max   T_min  perc_T_st_-20  perc_T_-20_0  ...  perc_C_rate_3_4  \
# 0    30.008  22.695            0.0           0.0  ...         0.000000
# 1    56.184  22.695            0.0           0.0  ...         7.627443
# 2    56.184  22.695            0.0           0.0  ...        10.718102
# 3    56.184  22.695            0.0           0.0  ...        10.234064
# 4    56.184  22.695            0.0           0.0  ...        11.467772
# ..      ...     ...            ...           ...  ...              ...
# 857  72.733  19.677            0.0           0.0  ...        11.182165
# 858  72.733  19.677            0.0           0.0  ...        11.183089
# 859  72.733  19.677            0.0           0.0  ...        11.183476
# 860  72.733  19.677            0.0           0.0  ...        11.168307
# 861  72.733  19.677            0.0           0.0  ...        11.176099
#
#      perc_C_rate_4_6  perc_C_rate_6_8  perc_C_rate_gt_8  Q_norm_at_3.8_V  \
# 0           0.000000              0.0               0.0         0.282235
# 1           0.000000              0.0               0.0         0.281179
# 2           0.000000              0.0               0.0         0.280125
# 3           0.000000              0.0               0.0         0.279074
# 4           0.000000              0.0               0.0         0.278024
# ..               ...              ...               ...              ...
# 857         1.639649              0.0               0.0         0.028254
# 858         1.640758              0.0               0.0         0.027570
# 859         1.641649              0.0               0.0         0.026887
# 860         1.639422              0.0               0.0         0.026198
# 861         1.639049              0.0               0.0         0.026198
#
#      Q_norm_at_3.6_V  Q_norm_at_3.4_V  Q_norm_at_3.2_V    R_norm         SOH
# 0           0.510637         0.753417         0.933498  1.000000  100.000000
# 1           0.509629         0.751993         0.931894  1.000000   99.237565
# 2           0.508623         0.750571         0.930292  0.992013   99.154332
# 3           0.507619         0.749154         0.928695  1.008557   98.797904
# 4           0.506617         0.747738         0.927099  1.016629   98.716588
# ..               ...              ...              ...       ...         ...
# 857         0.141491         0.284211         0.435405  1.819508   73.339336
# 858         0.140769         0.283595         0.434970  1.832016   73.551804
# 859         0.140048         0.282980         0.434537  1.830476   73.417780
# 860         0.139320         0.282360         0.434099  1.830476   74.062738
# 861         0.139320         0.282360         0.434099  1.830476   65.581416
#
# [862 rows x 32 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

print("Hello")

#display = df.iloc[53455:53462]
display = cycle_based_df

plt.figure(figsize=(20,20))

fig, axes = plt.subplots(nrows=2, sharex=True, figsize=(10,10))

sns.lineplot(data=display, x='EFC', y='SOH',ax=axes[0])
sns.lineplot(data=display, x='EFC', y='R_norm',ax=axes[1])

for ax in axes:
    ax.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()
# Out:
# Hello

# %%
batt_labels = ['battery23','battery30','battery01']

complete_df = pd.DataFrame([])
for label in batt_labels:
    csv_name = label + ".csv"
    base_path = "battery_alt_dataset/battery_alt_dataset/regular_alt_batteries/"
    full_path = base_path + csv_name
    df_in = pd.read_csv(full_path)
    df = clean_data(df_in)
    cycle_df = generate_cycle_based_data(label,df)
    complete_df = pd.concat([complete_df,cycle_df],axis=0)

complete_df.to_csv("cycle_complete.csv")
complete_df
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_125916\1036982236.py:8: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_in = pd.read_csv(full_path)
#     batt_label  isRefCycle     time_sec         EFC  E_cum_norm      T_avg  \
# 0    battery23        True     9354.481    1.000000    1.000000  25.049473
# 1    battery23       False    15704.557    2.003095    1.918082  27.975341
# 2    battery23       False    23792.864    3.007057    2.837870  28.833235
# 3    battery23       False    28679.085    4.009007    3.755136  29.889525
# 4    battery23       False    33559.086    5.008665    4.670160  30.658347
# ..         ...         ...          ...         ...         ...        ...
# 857  battery01       False  4928557.253  718.824908  651.889754  34.771664
# 858  battery01       False  4932961.391  719.560426  652.527105  34.777757
# 859  battery01       False  4937646.269  720.294604  653.161623  34.783362
# 860  battery01        True  4944285.651  721.035231  653.836018  34.780949
# 861  battery01       False  4946085.940  721.691045  654.414061  34.784865
#
#       T_max   T_min  perc_T_st_-20  perc_T_-20_0  ...  perc_C_rate_3_4  \
# 0    28.178  22.503            0.0           0.0  ...         0.000000
# 1    65.706  22.503            0.0           0.0  ...         0.000000
# 2    66.376  22.480            0.0           0.0  ...         0.000000
# 3    66.448  22.480            0.0           0.0  ...         0.000000
# 4    67.082  22.480            0.0           0.0  ...         0.000000
# ..      ...     ...            ...           ...  ...              ...
# 857  72.733  19.677            0.0           0.0  ...        11.182165
# 858  72.733  19.677            0.0           0.0  ...        11.183089
# 859  72.733  19.677            0.0           0.0  ...        11.183476
# 860  72.733  19.677            0.0           0.0  ...        11.168307
# 861  72.733  19.677            0.0           0.0  ...        11.176099
#
#      perc_C_rate_4_6  perc_C_rate_6_8  perc_C_rate_gt_8  Q_norm_at_3.8_V  \
# 0           0.000000         0.000000               0.0         0.284855
# 1           2.160276         1.668256               0.0         0.283205
# 2           2.872300         2.183969               0.0         0.281553
# 3           3.573825         2.714959               0.0         0.279904
# 4           4.025194         3.134145               0.0         0.278259
# ..               ...              ...               ...              ...
# 857         1.639649         0.000000               0.0         0.028254
# 858         1.640758         0.000000               0.0         0.027570
# 859         1.641649         0.000000               0.0         0.026887
# 860         1.639422         0.000000               0.0         0.026198
# 861         1.639049         0.000000               0.0         0.026198
#
#      Q_norm_at_3.6_V  Q_norm_at_3.4_V  Q_norm_at_3.2_V    R_norm         SOH
# 0           0.512524         0.754284         0.932640  1.000000  100.000000
# 1           0.510990         0.752092         0.930263  1.000000  100.309485
# 2           0.509455         0.749897         0.927884  0.984366  100.396220
# 3           0.507923         0.747707         0.925510  0.988749  100.195027
# 4           0.506395         0.745522         0.923141  0.996090   99.965720
# ..               ...              ...              ...       ...         ...
# 857         0.141491         0.284211         0.435405  1.819508   73.339336
# 858         0.140769         0.283595         0.434970  1.832016   73.551804
# 859         0.140048         0.282980         0.434537  1.830476   73.417780
# 860         0.139320         0.282360         0.434099  1.830476   74.062738
# 861         0.139320         0.282360         0.434099  1.830476   65.581416
#
# [1188 rows x 32 columns]

# %%
plt.figure(figsize=(20,20))

fig, axes = plt.subplots(nrows=6, sharex=True, figsize=(10,10))

display = complete_df
sns.lineplot(data=display, x='EFC', y='SOH',ax=axes[0], hue = 'batt_label')
sns.lineplot(data=display, x='EFC', y='R_norm',ax=axes[1], hue = 'batt_label')

sns.lineplot(data=display, x='EFC', y='Q_norm_at_3.8_V',ax=axes[2], hue = 'batt_label')
sns.lineplot(data=display, x='EFC', y='Q_norm_at_3.6_V',ax=axes[3], hue = 'batt_label')
sns.lineplot(data=display, x='EFC', y='Q_norm_at_3.4_V',ax=axes[4], hue = 'batt_label')
sns.lineplot(data=display, x='EFC', y='Q_norm_at_3.2_V',ax=axes[5], hue = 'batt_label')

for ax in axes:
    ax.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()
